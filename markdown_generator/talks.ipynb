# %% [markdown]
# # Talks markdown generator for agvaughan
#
# Takes a TSV of talks with metadata and converts them for use with [agvaughan.github.io](agvaughan.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `talks.py`. Run either from the `markdown_generator` folder after replacing `talks.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases, rather than Stuart's non-standard TSV format and citation style.

# %%
import pandas as pd
import os

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: title, type, url_slug, venue, date, location, talk_url, description, with a header at the top. Many of these fields can be blank, but the columns must be in the TSV.
#
# - Fields that cannot be blank: `title`, `url_slug`, `date`. All else can be blank. `type` defaults to "Talk"
# - `date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper.
#     - The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/talks/YYYY-MM-DD-[url_slug]`
#     - The combination of `url_slug` and `date` must be unique, as it will be the basis for your filenames
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %%
# !cat talks.tsv
# Out:
# title	type	url_slug	venue	date	location	talk_url	description
# "Compressive approaches for neuronal reconstruction using DNA barcodes Alexander Vaughan, Xiaoyin Chen, Anthony Zador, Cold Spring Harbor Laboratory"	Talk		Cosyne	2017-2-23	"Salt Lake City, UT"
# "Categorical representations of decision variables within OFC Alexander Vaughan, Junya Hirokawa, Adam Kepecs, Cold Spring Harbor Laboratory . . . ."	Talk		Cosyne	2015-3-5	"Salt Lake City, UT"
# "Electrons, fluorophores, and nucleotides: bridging the gaps in high-throughput connectomics"	Workshop (Organizer)		Cosyne Workshops	2017-2-27	"Snowbird, UT"
# The perils and promises (and methods) of sequence-based connectomics	Workshop Talk (Organizer)		Cosyne Workshops	2017-2-27	"Snowbird, UT"
# Structured and cell-type-specific encoding of decision variables in orbitofrontal cortex	Talk		Annual Meeting of the Japan Neuroscience Society	2020-07-31	"Kobe, JP"
# Categorical representations of decision variables within Oribito frontal cortex	Talk		Annual Meeting of the Society for Neuroscience	2016-7-1	"San Diego, CA"
# The representational content of rat orbitofrontal cortex during outcome anticipation.	Talk		CSHL Symposium	2014-05-01	"Cold Spring Harbor, NY"
# Interview with a Neuroscientist - Alex Vaughan	Podcast		Numenta - On Intelligence	2018-10-24	Podcast
# Fairness in AI Ð Lessons from Practice	Invited Talk		Wharton Customer Analytics	2021-5-17	Conference
# Molecular Tools For High-Throughput Neuronal Connectivity	Talk		Kavli Futures Symposium	2018-10-27	"Santa Monica, California"
# MapNeuro - A platform for neural connectivity	Talk - Award		Alexandria LaunchLabs Seed Capital Prize Talk	2018-7-29	"New York, NY"
# Molecular Tools For High-Throughput Neuronal Connectivity	Invited Talk		CELL-NERF Symposiuum (Neurotechnologies)	2018-9-30	"Leuven, Belgium"
# NeuroTech for Good (And Bad)	Talk		AI For Good	2022-2-23	Talk
# The business of neurotech	Talk		Wharton Neuroscience  - Introduction to Brain Science	2022-3-1	"Philadelphia, PA"

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
talks = pd.read_csv("talks.tsv", sep="\t", header=0)
talks = talks.fillna(' ', inplace=False)
talks
# Out:
#                                                 title  \
# 0   Compressive approaches for neuronal reconstruc...
# 1   Categorical representations of decision variab...
# 2   Electrons, fluorophores, and nucleotides: brid...
# 3   The perils and promises (and methods) of seque...
# 4   Structured and cell-type-specific encoding of ...
# 5   Categorical representations of decision variab...
# 6   The representational content of rat orbitofron...
# 7      Interview with a Neuroscientist - Alex Vaughan
# 8              Fairness in AI Ð Lessons from Practice
# 9   Molecular Tools For High-Throughput Neuronal C...
# 10      MapNeuro - A platform for neural connectivity
# 11  Molecular Tools For High-Throughput Neuronal C...
# 12                       NeuroTech for Good (And Bad)
# 13                          The business of neurotech
#
#                          type url_slug  \
# 0                        Talk
# 1                        Talk
# 2        Workshop (Organizer)
# 3   Workshop Talk (Organizer)
# 4                        Talk
# 5                        Talk
# 6                        Talk
# 7                     Podcast
# 8                Invited Talk
# 9                        Talk
# 10               Talk - Award
# 11               Invited Talk
# 12                       Talk
# 13                       Talk
#
#                                                 venue        date  \
# 0                                              Cosyne   2017-2-23
# 1                                              Cosyne    2015-3-5
# 2                                    Cosyne Workshops   2017-2-27
# 3                                    Cosyne Workshops   2017-2-27
# 4    Annual Meeting of the Japan Neuroscience Society  2020-07-31
# 5      Annual Meeting of the Society for Neuroscience    2016-7-1
# 6                                      CSHL Symposium  2014-05-01
# 7                           Numenta - On Intelligence  2018-10-24
# 8                          Wharton Customer Analytics   2021-5-17
# 9                             Kavli Futures Symposium  2018-10-27
# 10      Alexandria LaunchLabs Seed Capital Prize Talk   2018-7-29
# 11           CELL-NERF Symposiuum (Neurotechnologies)   2018-9-30
# 12                                        AI For Good   2022-2-23
# 13  Wharton Neuroscience  - Introduction to Brain ...    2022-3-1
#
#                     location talk_url description
# 0         Salt Lake City, UT
# 1         Salt Lake City, UT
# 2               Snowbird, UT
# 3               Snowbird, UT
# 4                   Kobe, JP
# 5              San Diego, CA
# 6     Cold Spring Harbor, NY
# 7                    Podcast
# 8                 Conference
# 9   Santa Monica, California
# 10              New York, NY
# 11           Leuven, Belgium
# 12                      Talk
# 13          Philadelphia, PA

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    if type(text) is str:
        return "".join(html_escape_table.get(c,c) for c in text)
    else:
        return "False"

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
loc_dict = {}

for row, item in talks.iterrows():
    
    print(item)
    
    md_filename = str(item.date) + "-" + item.url_slug + ".md"
    html_filename = str(item.date) + "-" + item.url_slug 
    year = item.date[:4]
    
    md = "---\ntitle: \""   + item.title + '"\n'
    md += "collection: talks" + "\n"
    
    if len(str(item.type)) > 3:
        md += 'type: "' + item.type + '"\n'
    else:
        md += 'type: "Talk"\n'
    
    md += "permalink: /talks/" + html_filename + "\n"
    
    if len(str(item.venue)) > 3:
        md += 'venue: "' + item.venue + '"\n'
        
    if len(str(item.location)) > 3:
        md += "date: " + str(item.date) + "\n"
    
    if len(str(item.location)) > 3:
        md += 'location: "' + str(item.location) + '"\n'
           
    md += "---\n"
    
    
    if len(str(item.talk_url)) > 3:
        md += "\n[More information here](" + item.talk_url + ")\n" 
        
    
    if len(str(item.description)) > 3:
        md += "\n" + html_escape(item.description) + "\n"
        
        
    md_filename = os.path.basename(md_filename)
    #print(md)
    
    with open("../_talks/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# title          Compressive approaches for neuronal reconstruc...
# type                                                        Talk
# url_slug
# venue                                                     Cosyne
# date                                                   2017-2-23
# location                                      Salt Lake City, UT
# talk_url
# description
# Name: 0, dtype: object
# title          Categorical representations of decision variab...
# type                                                        Talk
# url_slug
# venue                                                     Cosyne
# date                                                    2015-3-5
# location                                      Salt Lake City, UT
# talk_url
# description
# Name: 1, dtype: object
# title          Electrons, fluorophores, and nucleotides: brid...
# type                                        Workshop (Organizer)
# url_slug
# venue                                           Cosyne Workshops
# date                                                   2017-2-27
# location                                            Snowbird, UT
# talk_url
# description
# Name: 2, dtype: object
# title          The perils and promises (and methods) of seque...
# type                                   Workshop Talk (Organizer)
# url_slug
# venue                                           Cosyne Workshops
# date                                                   2017-2-27
# location                                            Snowbird, UT
# talk_url
# description
# Name: 3, dtype: object
# title          Structured and cell-type-specific encoding of ...
# type                                                        Talk
# url_slug
# venue           Annual Meeting of the Japan Neuroscience Society
# date                                                  2020-07-31
# location                                                Kobe, JP
# talk_url
# description
# Name: 4, dtype: object
# title          Categorical representations of decision variab...
# type                                                        Talk
# url_slug
# venue             Annual Meeting of the Society for Neuroscience
# date                                                    2016-7-1
# location                                           San Diego, CA
# talk_url
# description
# Name: 5, dtype: object
# title          The representational content of rat orbitofron...
# type                                                        Talk
# url_slug
# venue                                             CSHL Symposium
# date                                                  2014-05-01
# location                                  Cold Spring Harbor, NY
# talk_url
# description
# Name: 6, dtype: object
# title          Interview with a Neuroscientist - Alex Vaughan
# type                                                  Podcast
# url_slug
# venue                               Numenta - On Intelligence
# date                                               2018-10-24
# location                                              Podcast
# talk_url
# description
# Name: 7, dtype: object
# title          Fairness in AI Ð Lessons from Practice
# type                                     Invited Talk
# url_slug
# venue                      Wharton Customer Analytics
# date                                        2021-5-17
# location                                   Conference
# talk_url
# description
# Name: 8, dtype: object
# title          Molecular Tools For High-Throughput Neuronal C...
# type                                                        Talk
# url_slug
# venue                                    Kavli Futures Symposium
# date                                                  2018-10-27
# location                                Santa Monica, California
# talk_url
# description
# Name: 9, dtype: object
# title          MapNeuro - A platform for neural connectivity
# type                                            Talk - Award
# url_slug
# venue          Alexandria LaunchLabs Seed Capital Prize Talk
# date                                               2018-7-29
# location                                        New York, NY
# talk_url
# description
# Name: 10, dtype: object
# title          Molecular Tools For High-Throughput Neuronal C...
# type                                                Invited Talk
# url_slug
# venue                   CELL-NERF Symposiuum (Neurotechnologies)
# date                                                   2018-9-30
# location                                         Leuven, Belgium
# talk_url
# description
# Name: 11, dtype: object
# title          NeuroTech for Good (And Bad)
# type                                   Talk
# url_slug
# venue                           AI For Good
# date                              2022-2-23
# location                               Talk
# talk_url
# description
# Name: 12, dtype: object
# title                                  The business of neurotech
# type                                                        Talk
# url_slug
# venue          Wharton Neuroscience  - Introduction to Brain ...
# date                                                    2022-3-1
# location                                        Philadelphia, PA
# talk_url
# description
# Name: 13, dtype: object

# %% [markdown]
# These files are in the talks directory, one directory below where we're working from.

# %%
# !ls ../_talks
# Out:
# 2014-05-01- .md 2017-2-23- .md  2018-10-27- .md 2020-07-31- .md 2022-3-1- .md
# 2015-3-5- .md   2017-2-27- .md  2018-7-29- .md  2021-5-17- .md
# 2016-7-1- .md   2018-10-24- .md 2018-9-30- .md  2022-2-23- .md

# %%
# !cat ../_talks/2013-03-01-tutorial-1.md
# Out:
# cat: ../_talks/2013-03-01-tutorial-1.md: No such file or directory
